# %% [markdown]
# # Agastya Data Solutions
#
# ### Internship evaluation test

# %% [markdown]
# #### Name: Pavan Kumar Tripathi
# #### Contact Info: 7780145931

# %% [markdown]
# 1. Benchmark Strategy:
# Our Benchmark is going to be simple and basic, we are going to invest our initial investment equally
# among all the 50 stocks during the beginning of the simulation and hold it till the end and get the
# portfolio equity curve.
# Initial Investment: INR 10,00,000 (10 Lakhs)
# Start Period: 2020 – 10 – 01 (2020 Oct, 01)
# End Period: Till Present
# Equity Curve: Sum total of daily value of all stocks (This is just Illustrative, please code as per your
# understanding, we are interested in the equity curve value only, not the steps)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import pandas_datareader as data
import matplotlib.pyplot as plt


start = '2020-10-01'
end = '2022-10-27'

df = data.DataReader('BHEL.NS','yahoo',start,end)

# %%
top50 = ["ADANIPORTS.NS","ASIANPAINT.NS","AXISBANK.NS","BAJFINANCE.NS","BAJAJFINSV.NS",
          "BHARTIARTL.NS","BPCL.NS","BRITANNIA.NS","CIPLA.NS","COALINDIA.NS","DIVISLAB.NS",
          "DRREDDY.NS","EICHERMOT.NS","GRASIM.NS","HCLTECH.NS","HDFC.NS","HDFCBANK.NS","HDFCLIFE.NS",
          "HEROMOTOCO.NS","HINDALCO.NS","HINDUNILVR.NS","ICICIBANK.NS","INDUSINDBK.NS","INFY.NS","IOC.NS",
          "ITC.NS","JSWSTEEL.NS","KOTAKBANK.NS","LT.NS","M&M.NS","MARUTI.NS","NESTLEIND.NS","NTPC.NS","ONGC.NS",
          "POWERGRID.NS","RELIANCE.NS","SBIN.NS","SBILIFE.NS","SUNPHARMA.NS","TATACONSUM.NS","TATAMOTORS.NS",
          "TATASTEEL.NS","TCS.NS","TECHM.NS","TITAN.NS","ULTRACEMCO.NS","UPL.NS","WIPRO.NS"]

# %%
x = [i+"_open" for i in top50]
y = [i+"_close" for i in top50]
q = [i+"_qty" for i in top50]
dv = [i+"_dv" for i in top50]

z = x+y+q+dv

# %%
lst = pd.DataFrame(columns=z)

# %%
lst
# Out:
# Empty DataFrame
# Columns: [ADANIPORTS.NS_open, ASIANPAINT.NS_open, AXISBANK.NS_open, BAJFINANCE.NS_open, BAJAJFINSV.NS_open, BHARTIARTL.NS_open, BPCL.NS_open, BRITANNIA.NS_open, CIPLA.NS_open, COALINDIA.NS_open, DIVISLAB.NS_open, DRREDDY.NS_open, EICHERMOT.NS_open, GRASIM.NS_open, HCLTECH.NS_open, HDFC.NS_open, HDFCBANK.NS_open, HDFCLIFE.NS_open, HEROMOTOCO.NS_open, HINDALCO.NS_open, HINDUNILVR.NS_open, ICICIBANK.NS_open, INDUSINDBK.NS_open, INFY.NS_open, IOC.NS_open, ITC.NS_open, JSWSTEEL.NS_open, KOTAKBANK.NS_open, LT.NS_open, M&M.NS_open, MARUTI.NS_open, NESTLEIND.NS_open, NTPC.NS_open, ONGC.NS_open, POWERGRID.NS_open, RELIANCE.NS_open, SBIN.NS_open, SBILIFE.NS_open, SUNPHARMA.NS_open, TATACONSUM.NS_open, TATAMOTORS.NS_open, TATASTEEL.NS_open, TCS.NS_open, TECHM.NS_open, TITAN.NS_open, ULTRACEMCO.NS_open, UPL.NS_open, WIPRO.NS_open, ADANIPORTS.NS_close, ASIANPAINT.NS_close, AXISBANK.NS_close, BAJFINANCE.NS_close, BAJAJFINSV.NS_close, BHARTIARTL.NS_close, BPCL.NS_close, BRITANNIA.NS_close, CIPLA.NS_close, COALINDIA.NS_close, DIVISLAB.NS_close, DRREDDY.NS_close, EICHERMOT.NS_close, GRASIM.NS_close, HCLTECH.NS_close, HDFC.NS_close, HDFCBANK.NS_close, HDFCLIFE.NS_close, HEROMOTOCO.NS_close, HINDALCO.NS_close, HINDUNILVR.NS_close, ICICIBANK.NS_close, INDUSINDBK.NS_close, INFY.NS_close, IOC.NS_close, ITC.NS_close, JSWSTEEL.NS_close, KOTAKBANK.NS_close, LT.NS_close, M&M.NS_close, MARUTI.NS_close, NESTLEIND.NS_close, NTPC.NS_close, ONGC.NS_close, POWERGRID.NS_close, RELIANCE.NS_close, SBIN.NS_close, SBILIFE.NS_close, SUNPHARMA.NS_close, TATACONSUM.NS_close, TATAMOTORS.NS_close, TATASTEEL.NS_close, TCS.NS_close, TECHM.NS_close, TITAN.NS_close, ULTRACEMCO.NS_close, UPL.NS_close, WIPRO.NS_close, ADANIPORTS.NS_qty, ASIANPAINT.NS_qty, AXISBANK.NS_qty, BAJFINANCE.NS_qty, ...]
# Index: []
#
# [0 rows x 192 columns]

# %%
invstm = 1000000
pps = invstm//50
pps
# Out:
# 20000

# %%
for i in top50:
    df = data.DataReader(i,'yahoo',start,end)
    lst[i+"_open"] = df.Open
    lst[i+"_close"] = df.Close
    lst[i+"_qty"] = pps//lst[i+"_open"].iloc[0]
    lst[i+"_dv"] = lst[i+"_close"] * lst[i+"_qty"]

# %%
lst.head()
# Out:
#             ADANIPORTS.NS_open  ASIANPAINT.NS_open  AXISBANK.NS_open  \
# Date
# 2020-10-01          345.500000         2007.000000        430.200012
# 2020-10-05          355.899994         2040.449951        444.049988
# 2020-10-06          356.000000         2050.000000        449.500000
# 2020-10-07          362.549988         2080.000000        447.000000
# 2020-10-08          359.799988         2104.500000        455.549988
#
#             BAJFINANCE.NS_open  BAJAJFINSV.NS_open  BHARTIARTL.NS_open  \
# Date
# 2020-10-01         3325.000000          590.700012          426.000000
# 2020-10-05         3465.000000          609.000000          432.350006
# 2020-10-06         3439.899902          595.700012          427.000000
# 2020-10-07         3400.000000          592.000000          427.799988
# 2020-10-08         3354.000000          595.000000          426.000000
#
#             BPCL.NS_open  BRITANNIA.NS_open  CIPLA.NS_open  COALINDIA.NS_open  \
# Date
# 2020-10-01    358.000000        3820.000000     779.799988         117.099998
# 2020-10-05    353.299988        3815.000000     776.000000         117.949997
# 2020-10-06    356.700012        3870.000000     782.000000         119.349998
# 2020-10-07    353.000000        3780.000000     780.000000         117.099998
# 2020-10-08    344.899994        3798.899902     775.000000         114.699997
#
#             ...  SUNPHARMA.NS_dv  TATACONSUM.NS_dv  TATAMOTORS.NS_dv  \
# Date        ...
# 2020-10-01  ...     19769.099762      19854.900238      19624.500000
# 2020-10-05  ...     20400.899048      19638.449524      19683.299103
# 2020-10-06  ...     20320.949524      19718.400238      21278.250000
# 2020-10-07  ...     19958.250000      19696.949524      20727.000000
# 2020-10-08  ...     20439.899048      19041.750000      20719.649551
#
#             TATASTEEL.NS_dv     TCS.NS_dv   TECHM.NS_dv   TITAN.NS_dv  \
# Date
# 2020-10-01     19999.259415  17664.149658  20562.500000  19178.400391
# 2020-10-05     20950.039749  18940.600342  21031.250000  19109.599609
# 2020-10-06     20681.520920  19000.100342  21185.000610  19199.199219
# 2020-10-07     20336.280334  19151.649658  21158.749390  20064.000000
# 2020-10-08     20476.020920  19779.899658  21507.499695  20066.400391
#
#             ULTRACEMCO.NS_dv     UPL.NS_dv   WIPRO.NS_dv
# Date
# 2020-10-01      16391.000000  19720.349762  19722.149231
# 2020-10-05      16188.599609  19776.900238  21038.850769
# 2020-10-06      16544.400391  19872.449524  20793.149231
# 2020-10-07      16853.400391  19923.150238  21123.899231
# 2020-10-08      17384.000000  19866.599762  22645.350769
#
# [5 rows x 192 columns]

# %%
dv = [i+"_dv" for i in top50]
# dv

# %%
lst["ec"] = lst[dv].sum(axis=1)
lst.head()
# Out:
#             ADANIPORTS.NS_open  ASIANPAINT.NS_open  AXISBANK.NS_open  \
# Date
# 2020-10-01          345.500000         2007.000000        430.200012
# 2020-10-05          355.899994         2040.449951        444.049988
# 2020-10-06          356.000000         2050.000000        449.500000
# 2020-10-07          362.549988         2080.000000        447.000000
# 2020-10-08          359.799988         2104.500000        455.549988
#
#             BAJFINANCE.NS_open  BAJAJFINSV.NS_open  BHARTIARTL.NS_open  \
# Date
# 2020-10-01         3325.000000          590.700012          426.000000
# 2020-10-05         3465.000000          609.000000          432.350006
# 2020-10-06         3439.899902          595.700012          427.000000
# 2020-10-07         3400.000000          592.000000          427.799988
# 2020-10-08         3354.000000          595.000000          426.000000
#
#             BPCL.NS_open  BRITANNIA.NS_open  CIPLA.NS_open  COALINDIA.NS_open  \
# Date
# 2020-10-01    358.000000        3820.000000     779.799988         117.099998
# 2020-10-05    353.299988        3815.000000     776.000000         117.949997
# 2020-10-06    356.700012        3870.000000     782.000000         119.349998
# 2020-10-07    353.000000        3780.000000     780.000000         117.099998
# 2020-10-08    344.899994        3798.899902     775.000000         114.699997
#
#             ...  TATACONSUM.NS_dv  TATAMOTORS.NS_dv  TATASTEEL.NS_dv  \
# Date        ...
# 2020-10-01  ...      19854.900238      19624.500000     19999.259415
# 2020-10-05  ...      19638.449524      19683.299103     20950.039749
# 2020-10-06  ...      19718.400238      21278.250000     20681.520920
# 2020-10-07  ...      19696.949524      20727.000000     20336.280334
# 2020-10-08  ...      19041.750000      20719.649551     20476.020920
#
#                TCS.NS_dv   TECHM.NS_dv   TITAN.NS_dv  ULTRACEMCO.NS_dv  \
# Date
# 2020-10-01  17664.149658  20562.500000  19178.400391      16391.000000
# 2020-10-05  18940.600342  21031.250000  19109.599609      16188.599609
# 2020-10-06  19000.100342  21185.000610  19199.199219      16544.400391
# 2020-10-07  19151.649658  21158.749390  20064.000000      16853.400391
# 2020-10-08  19779.899658  21507.499695  20066.400391      17384.000000
#
#                UPL.NS_dv   WIPRO.NS_dv             ec
# Date
# 2020-10-01  19720.349762  19722.149231  925560.694962
# 2020-10-05  19776.900238  21038.850769  931887.771893
# 2020-10-06  19872.449524  20793.149231  941017.895061
# 2020-10-07  19923.150238  21123.899231  940652.258881
# 2020-10-08  19866.599762  22645.350769  946102.131824
#
# [5 rows x 193 columns]

# %%
# lst.reset_index(inplace = True)

# %%
lst.ec.plot(label = "benchmark",figsize=(12, 7))
plt.title("Daily Closing Price of investment", fontsize=20)
plt.legend(loc="upper left")

# %% [markdown]
# # Create a strategy to beat the benchmark

# %%
past100 = {}
for i in top50:
    past100[i] = lst[i+"_close"].iloc[-1]/(lst[i+"_close"].iloc[-100]-1)

# %%
past100
# Out:
# {'ADANIPORTS.NS': 1.1114494151644396,
#  'ASIANPAINT.NS': 1.054593040008135,
#  'AXISBANK.NS': 1.353171729901334,
#  'BAJFINANCE.NS': 1.1566066949423455,
#  'BAJAJFINSV.NS': 1.2860758163119839,
#  'BHARTIARTL.NS': 1.1919766237577498,
#  'BPCL.NS': 0.9341281118905125,
#  'BRITANNIA.NS': 1.064125828514629,
#  'CIPLA.NS': 1.2145424340727173,
#  'COALINDIA.NS': 1.2290816015126753,
#  'DIVISLAB.NS': 1.0413395444688314,
#  'DRREDDY.NS': 1.0350772517429132,
#  'EICHERMOT.NS': 1.3823786541282481,
#  'GRASIM.NS': 1.2883933012676634,
#  'HCLTECH.NS': 0.9904511025221929,
#  'HDFC.NS': 1.0469830854585995,
#  'HDFCBANK.NS': 1.0544478887314936,
#  'HDFCLIFE.NS': 0.8858234821118914,
#  'HEROMOTOCO.NS': 1.0108411576807665,
#  'HINDALCO.NS': 1.0163893872987908,
#  'HINDUNILVR.NS': 1.099543880786864,
#  'ICICIBANK.NS': 1.2436432659696686,
#  'INDUSINDBK.NS': 1.2374093091141494,
#  'INFY.NS': 1.0021371737386429,
#  'IOC.NS': 0.8771404272330185,
#  'ITC.NS': 1.272727170617403,
#  'JSWSTEEL.NS': 1.2104371908631095,
#  'KOTAKBANK.NS': 1.0039565986538588,
#  'LT.NS': 1.1895763246075792,
#  'M&M.NS': 1.259329532105982,
#  'MARUTI.NS': 1.1736619602083775,
#  'NESTLEIND.NS': 1.172582993593477,
#  'NTPC.NS': 1.1081168434836648,
#  'ONGC.NS': 0.8751659874513182,
#  'POWERGRID.NS': 0.995111083984375,
#  'RELIANCE.NS': 0.8821845968485694,
#  'SBIN.NS': 1.2505933644316343,
#  'SBILIFE.NS': 1.098890494746903,
#  'SUNPHARMA.NS': 1.1707557609037922,
#  'TATACONSUM.NS': 1.0227785400754277,
#  'TATAMOTORS.NS': 0.9461592434020166,
#  'TATASTEEL.NS': 0.985529117940853,
#  'TCS.NS': 0.9180756849801779,
#  'TECHM.NS': 0.9380503554663158,
#  'TITAN.NS': 1.227103643760763,
#  'ULTRACEMCO.NS': 1.1336685002206268,
#  'UPL.NS': 0.9190788912620591,
#  'WIPRO.NS': 0.8064278058935392}

# %%
best = sorted(past100.items(), key=lambda x: x[1],reverse=True)
best[:10]
# Out:
# [('EICHERMOT.NS', 1.3823786541282481),
#  ('AXISBANK.NS', 1.353171729901334),
#  ('GRASIM.NS', 1.2883933012676634),
#  ('BAJAJFINSV.NS', 1.2860758163119839),
#  ('ITC.NS', 1.272727170617403),
#  ('M&M.NS', 1.259329532105982),
#  ('SBIN.NS', 1.2505933644316343),
#  ('ICICIBANK.NS', 1.2436432659696686),
#  ('INDUSINDBK.NS', 1.2374093091141494),
#  ('COALINDIA.NS', 1.2290816015126753)]

# %%
top10 = []
for i in range(10):
    top10.append(best[i][0])

top10
# Out:
# ['EICHERMOT.NS',
#  'AXISBANK.NS',
#  'GRASIM.NS',
#  'BAJAJFINSV.NS',
#  'ITC.NS',
#  'M&M.NS',
#  'SBIN.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'COALINDIA.NS']

# %%
invstm = 1000000
pps1 = invstm//10
pps1
# Out:
# 100000

# %%
x1 = [i+"_open" for i in top10]
y1 = [i+"_close" for i in top10]
q1 = [i+"_qty" for i in top10]
dv1 = [i+"_dv" for i in top10]

z1 = x1+y1+q1+dv1

# %%
lst1 = pd.DataFrame(columns=z1)
lst1
# Out:
# Empty DataFrame
# Columns: [EICHERMOT.NS_open, AXISBANK.NS_open, GRASIM.NS_open, BAJAJFINSV.NS_open, ITC.NS_open, M&M.NS_open, SBIN.NS_open, ICICIBANK.NS_open, INDUSINDBK.NS_open, COALINDIA.NS_open, EICHERMOT.NS_close, AXISBANK.NS_close, GRASIM.NS_close, BAJAJFINSV.NS_close, ITC.NS_close, M&M.NS_close, SBIN.NS_close, ICICIBANK.NS_close, INDUSINDBK.NS_close, COALINDIA.NS_close, EICHERMOT.NS_qty, AXISBANK.NS_qty, GRASIM.NS_qty, BAJAJFINSV.NS_qty, ITC.NS_qty, M&M.NS_qty, SBIN.NS_qty, ICICIBANK.NS_qty, INDUSINDBK.NS_qty, COALINDIA.NS_qty, EICHERMOT.NS_dv, AXISBANK.NS_dv, GRASIM.NS_dv, BAJAJFINSV.NS_dv, ITC.NS_dv, M&M.NS_dv, SBIN.NS_dv, ICICIBANK.NS_dv, INDUSINDBK.NS_dv, COALINDIA.NS_dv]
# Index: []
#
# [0 rows x 40 columns]

# %%
for i in top10:
    df = data.DataReader(i,'yahoo',start,end)
    lst1[i+"_open"] = df.Open
    lst1[i+"_close"] = df.Close
    lst1[i+"_qty"] = pps1//lst1[i+"_open"].iloc[0]
    lst1[i+"_dv"] = lst1[i+"_close"] * lst1[i+"_qty"]

# %%
# lst.reset_index(inplace=True)
lst1.head()
# Out:
#             EICHERMOT.NS_open  AXISBANK.NS_open  GRASIM.NS_open  \
# Date
# 2020-10-01        2190.000000        430.200012      749.200012
# 2020-10-05        2210.649902        444.049988      752.200012
# 2020-10-06        2223.800049        449.500000      750.250000
# 2020-10-07        2208.000000        447.000000      755.000000
# 2020-10-08        2253.000000        455.549988      765.000000
#
#             BAJAJFINSV.NS_open  ITC.NS_open  M&M.NS_open  SBIN.NS_open  \
# Date
# 2020-10-01          590.700012   174.500000   614.700012    187.000000
# 2020-10-05          609.000000   171.100006   615.000000    192.000000
# 2020-10-06          595.700012   169.500000   611.599976    191.100006
# 2020-10-07          592.000000   170.000000   629.900024    192.550003
# 2020-10-08          595.000000   170.100006   634.150024    191.350006
#
#             ICICIBANK.NS_open  INDUSINDBK.NS_open  COALINDIA.NS_open  ...  \
# Date                                                                  ...
# 2020-10-01         358.250000          540.000000         117.099998  ...
# 2020-10-05         370.750000          593.200012         117.949997  ...
# 2020-10-06         377.100006          615.950012         119.349998  ...
# 2020-10-07         379.299988          620.950012         117.099998  ...
# 2020-10-08         385.000000          620.000000         114.699997  ...
#
#             EICHERMOT.NS_dv  AXISBANK.NS_dv   GRASIM.NS_dv  BAJAJFINSV.NS_dv  \
# Date
# 2020-10-01     98894.245605   102938.402832  100355.148376     102305.837524
# 2020-10-05     99456.745605   103042.798584   99769.953247      99391.433350
# 2020-10-06     98892.004395   104318.798584  100774.101624     101322.256287
# 2020-10-07    100710.000000   105119.201416  101033.453247      99798.729126
# 2020-10-08     99396.002197   104840.798584  102456.546753      99235.956238
#
#                ITC.NS_dv      M&M.NS_dv     SBIN.NS_dv  ICICIBANK.NS_dv  \
# Date
# 2020-10-01  97897.053497   98844.303955  101620.201630    103006.803406
# 2020-10-05  96980.250000   98334.000000  100792.500000    104094.901703
# 2020-10-06  97352.696503  101638.803955  102314.403259    106187.401703
# 2020-10-07  97123.500000  102319.196045  101833.798370    106759.348297
# 2020-10-08  95776.946503  102732.303955  102261.000000    108112.500000
#
#             INDUSINDBK.NS_dv  COALINDIA.NS_dv
# Date
# 2020-10-01     109557.002258    100014.250000
# 2020-10-05     111286.747742    100995.201302
# 2020-10-06     115217.997742     99630.402603
# 2020-10-07     114533.495483     97625.847397
# 2020-10-08     114274.502258     96644.902603
#
# [5 rows x 40 columns]

# %%
dv1 = [i+"_dv" for i in top10]
dv1
# Out:
# ['EICHERMOT.NS_dv',
#  'AXISBANK.NS_dv',
#  'GRASIM.NS_dv',
#  'BAJAJFINSV.NS_dv',
#  'ITC.NS_dv',
#  'M&M.NS_dv',
#  'SBIN.NS_dv',
#  'ICICIBANK.NS_dv',
#  'INDUSINDBK.NS_dv',
#  'COALINDIA.NS_dv']

# %%
lst1["ec"] = lst1[dv1].sum(axis=1)
lst1.head()
# Out:
#             EICHERMOT.NS_open  AXISBANK.NS_open  GRASIM.NS_open  \
# Date
# 2020-10-01        2190.000000        430.200012      749.200012
# 2020-10-05        2210.649902        444.049988      752.200012
# 2020-10-06        2223.800049        449.500000      750.250000
# 2020-10-07        2208.000000        447.000000      755.000000
# 2020-10-08        2253.000000        455.549988      765.000000
#
#             BAJAJFINSV.NS_open  ITC.NS_open  M&M.NS_open  SBIN.NS_open  \
# Date
# 2020-10-01          590.700012   174.500000   614.700012    187.000000
# 2020-10-05          609.000000   171.100006   615.000000    192.000000
# 2020-10-06          595.700012   169.500000   611.599976    191.100006
# 2020-10-07          592.000000   170.000000   629.900024    192.550003
# 2020-10-08          595.000000   170.100006   634.150024    191.350006
#
#             ICICIBANK.NS_open  INDUSINDBK.NS_open  COALINDIA.NS_open  ...  \
# Date                                                                  ...
# 2020-10-01         358.250000          540.000000         117.099998  ...
# 2020-10-05         370.750000          593.200012         117.949997  ...
# 2020-10-06         377.100006          615.950012         119.349998  ...
# 2020-10-07         379.299988          620.950012         117.099998  ...
# 2020-10-08         385.000000          620.000000         114.699997  ...
#
#             AXISBANK.NS_dv   GRASIM.NS_dv  BAJAJFINSV.NS_dv     ITC.NS_dv  \
# Date
# 2020-10-01   102938.402832  100355.148376     102305.837524  97897.053497
# 2020-10-05   103042.798584   99769.953247      99391.433350  96980.250000
# 2020-10-06   104318.798584  100774.101624     101322.256287  97352.696503
# 2020-10-07   105119.201416  101033.453247      99798.729126  97123.500000
# 2020-10-08   104840.798584  102456.546753      99235.956238  95776.946503
#
#                 M&M.NS_dv     SBIN.NS_dv  ICICIBANK.NS_dv  INDUSINDBK.NS_dv  \
# Date
# 2020-10-01   98844.303955  101620.201630    103006.803406     109557.002258
# 2020-10-05   98334.000000  100792.500000    104094.901703     111286.747742
# 2020-10-06  101638.803955  102314.403259    106187.401703     115217.997742
# 2020-10-07  102319.196045  101833.798370    106759.348297     114533.495483
# 2020-10-08  102732.303955  102261.000000    108112.500000     114274.502258
#
#             COALINDIA.NS_dv            ec
# Date
# 2020-10-01    100014.250000  1.015433e+06
# 2020-10-05    100995.201302  1.014145e+06
# 2020-10-06     99630.402603  1.027649e+06
# 2020-10-07     97625.847397  1.026857e+06
# 2020-10-08     96644.902603  1.025731e+06
#
# [5 rows x 41 columns]

# %%
# lst1.reset_index(inplace = True)

# %%
lst.ec.plot(figsize=(12, 7),label = "benchmark")
lst1.ec.plot(figsize=(12, 7),label="strategy")
plt.title("Daily Closing Price of investment", fontsize=20)
plt.legend(loc="upper left")

# %% [markdown]
# # NIFTY

# %%
nf = data.DataReader('^NSEI','yahoo',start,end)
nf.head()
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2020-10-01  11428.599609  11347.049805  11364.450195  11416.950195  447700.0
# 2020-10-05  11578.049805  11452.299805  11487.799805  11503.349609  530600.0
# 2020-10-06  11680.299805  11564.299805  11603.450195  11662.400391  561400.0
# 2020-10-07  11763.049805  11629.349609  11679.250000  11738.849609  513400.0
# 2020-10-08  11905.700195  11791.150391  11835.400391  11834.599609  608800.0
#
#                Adj Close
# Date
# 2020-10-01  11416.950195
# 2020-10-05  11503.349609
# 2020-10-06  11662.400391
# 2020-10-07  11738.849609
# 2020-10-08  11834.599609

# %%
# nf.reset_index(inplace = True)

# %%
nf["qty"]= invstm//nf.Open.iloc[0]

# %%
nf.head()
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2020-10-01  11428.599609  11347.049805  11364.450195  11416.950195  447700.0
# 2020-10-05  11578.049805  11452.299805  11487.799805  11503.349609  530600.0
# 2020-10-06  11680.299805  11564.299805  11603.450195  11662.400391  561400.0
# 2020-10-07  11763.049805  11629.349609  11679.250000  11738.849609  513400.0
# 2020-10-08  11905.700195  11791.150391  11835.400391  11834.599609  608800.0
#
#                Adj Close   qty
# Date
# 2020-10-01  11416.950195  87.0
# 2020-10-05  11503.349609  87.0
# 2020-10-06  11662.400391  87.0
# 2020-10-07  11738.849609  87.0
# 2020-10-08  11834.599609  87.0

# %%
nf["ec"] = nf["qty"]*nf["Close"]

# %%
lst.ec.plot(figsize=(12, 7),label = "benchmark")
nf.ec.plot(figsize=(12, 7),label = "nifty")
lst1.ec.plot(figsize=(12, 7),label = "strategy")
plt.title("Daily Closing Price of investment", fontsize=20)
plt.legend(loc="upper left")

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
nf.ec()
# Out:
#                High           Low          Open         Close        Volume  \
# count    513.000000    513.000000    513.000000    513.000000  5.130000e+02
# mean   16098.709264  15902.470161  16015.151761  16007.123479  3.857879e+05
# std     1689.892272   1680.819541   1685.293042   1681.855382  1.753104e+05
# min    11428.599609  11347.049805  11364.450195  11416.950195  0.000000e+00
# 25%    15008.799805  14785.650391  14946.549805  14910.450195  2.600000e+05
# 50%    16403.699219  16203.250000  16296.599609  16294.599609  3.247000e+05
# 75%    17474.400391  17269.150391  17396.550781  17374.750000  4.980000e+05
# max    18604.449219  18445.300781  18602.349609  18477.050781  1.162400e+06
#
#           Adj Close    qty            ec
# count    513.000000  513.0  5.130000e+02
# mean   16007.123479   87.0  1.392620e+06
# std     1681.855382    0.0  1.463214e+05
# min    11416.950195   87.0  9.932747e+05
# 25%    14910.450195   87.0  1.297209e+06
# 50%    16294.599609   87.0  1.417630e+06
# 75%    17374.750000   87.0  1.511603e+06
# max    18477.050781   87.0  1.607503e+06

# %% [markdown]
# # CAGR

# %%
nf_cagr = ((nf.ec.iloc[-1]/nf.ec.iloc[0])**0.5)*100
lst_cagr = ((lst.ec.iloc[-1]/lst.ec.iloc[0])**0.5)*100
lst1_cagr = ((lst1.ec.iloc[-1]/lst1.ec.iloc[0])**0.5)*100

# %%
print(nf_cagr,lst_cagr,lst1_cagr)
# Out:
# 124.64199971406742 132.1913625311083 149.72525924069453

# %%
nf["dr"] = nf.ec.pct_change(1)
lst["dr"] = lst.ec.pct_change(1)
lst1["dr"] = lst1.ec.pct_change(1)

# %%
nf.head()

# %%
lst.ec.head()
# Out:
# Date
# 2020-10-01    925560.694962
# 2020-10-05    931887.771893
# 2020-10-06    941017.895061
# 2020-10-07    940652.258881
# 2020-10-08    946102.131824
# Name: ec, dtype: float64

# %%
nf["dr"] = nf['ec'].pct_change()

# %%
nf["dr"]
# Out:
# Date
# 2020-10-01         NaN
# 2020-10-05    0.007568
# 2020-10-06    0.013826
# 2020-10-07    0.006555
# 2020-10-08    0.008157
#                 ...
# 2022-10-20    0.002952
# 2022-10-21    0.000703
# 2022-10-24    0.008787
# 2022-10-25   -0.004196
# 2022-10-27    0.004565
# Name: dr, Length: 513, dtype: float64

# %% [markdown]
# # VOLATILITY

# %%
import math
nf_vol = (nf.dr.std()*math.sqrt(252))*100
lst_vol = (lst.dr.std()*math.sqrt(252))*100
lst1_vol = (lst1.dr.std()*math.sqrt(252))*100

# %%
print(nf_vol,lst_vol,lst1_vol)
# Out:
# 16.738956969973657 17.745637199421456 21.9220052698912

# %% [markdown]
# # SHARPE

# %%
nf_shr = (nf.dr.mean()/nf.dr.std())*math.sqrt(252)
lst_shr = (lst.dr.mean()/lst.dr.std())*math.sqrt(252)
lst1_shr = (lst1.dr.mean()/lst1.dr.std())*math.sqrt(252)

# %%
print(nf_shr,lst_shr,lst1_shr)
# Out:
# 1.3796548140999678 1.6348121191578806 1.9197720345076226

# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [163], in <cell line: 1>()
# ----> 1 import streamlit as st
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
# !pip install streamlit

# %%
# !python app.py
